# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
df=pd.read_csv('clothing.csv',index_col=0)
df.head()
# Out:
#                         _id                                  name  \
# 0  5d0b8aca0db7220b86cb4035   Joules Top Dog Underwear Three Pack
# 1  5d0b8aca0db7220b86cb4036    Figleaves Cheetah Satin Pyjama Set
# 2  5d0b8aca0db7220b86cb4037              Nike Solid 4" Swim Short
# 3  5d0b8aca0db7220b86cb4038                Collection Luxe Orchid
# 4  5d0b8aca0db7220b86cb4039  River Island White Sleeveless Blazer
#
#      brand_name  num_of_orders currency  regular_price  offer_price  \
# 0        joules              1      GBP           35.0         35.0
# 1     figleaves              1      GBP           25.0         25.0
# 2          nike              1      GBP           15.0         15.0
# 3          next              1      GBP          150.0        150.0
# 4  river island              1      GBP           55.0         55.0
#
#                                             url  \
# 0          www.next.co.uk/style/st355408#312838
# 1  https://www.next.co.uk/style/st324987#319571
# ...

# %%
df1=df[df['offer_price']<=df['regular_price']]

# %%
df1.brand_name.replace(np.NaN,'NA',inplace=True)
# Out:
# C:\Users\Bbbbb\Anaconda3\lib\site-packages\pandas\core\generic.py:6586: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df1[df1['regular_price'] <= 100 ]['regular_price'].plot(kind='kde')

# %%
df1[(df1['regular_price'] > 100) & (df1['regular_price'] <= 1000) ]['regular_price'].plot(kind='kde')

# %%
df1[(df1['regular_price'] > 1000) & (df1['regular_price'] <= 2000) ]['regular_price'].plot(kind='kde')

# %%
df1[(df1['regular_price'] > 1000) & (df1['regular_price'] <= 10000) ]['regular_price'].plot(kind='kde')

# %%
df1[(df1['regular_price'] > 10000) & (df1['regular_price'] <= 20000) ]['regular_price'].plot(kind='kde')

# %%
df1[(df1['regular_price'] > 50000) & (df1['regular_price'] <= 100000) ]['regular_price'].plot(kind='kde')

# %%
df1[(df1['regular_price'] > 100000) ]['regular_price'].plot(kind='kde')

# %%
df1[(df1['regular_price'] > 50000) & (df1['regular_price'] <= 100000) ].shape
# Out:
# (11, 9)

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x=df1[(df1['regular_price'] > 50000) & (df1['regular_price'] <= 100000)]['regular_price'],
                y=df1[(df1['regular_price'] > 50000) & (df1['regular_price'] <= 100000) ]['offer_price'],
                hue=df1[(df1['regular_price'] > 50000) & (df1['regular_price'] <= 100000)]['name'])

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=df1[(df1['regular_price'] > 100000) ]['regular_price'],y=df1[(df1['regular_price'] > 100000) ]['offer_price'],
                hue=df1[(df1['regular_price'] > 100000) ]['name'])

# %%
df1[(df1['regular_price'] != df1['offer_price'])]
# Out:
# (146172, 9)

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x=df1[(df1['regular_price'] != df1['offer_price'])]['regular_price'],
                y=df1[(df1['regular_price'] != df1['offer_price'])]['offer_price'],
               hue=df1[(df1['regular_price'] != df1['offer_price'])]['brand_name'],legend=None)

# %%
sns.boxplot(x=df1[(df1['regular_price'] > 50000) & (df1['regular_price'] <= 100000)]['regular_price'])

# %%
sns.boxplot(x=df1[(df1['regular_price'] > 50000) & (df1['regular_price'] <= 100000)]['offer_price'])

# %%
df1[(df1['regular_price'] > 100) & (df1['regular_price'] <= 1000) ]['regular_price'].plot(kind='box')

# %%
jeans=[]
trouser=[]
shirt=[]
glasses=[]
jumper=[]
hoodie=[]
skirt=[]
sneaker=[]
shoe=[]
bra=[]
for i in df1.name:
    if 'jeans' in i or 'Jeans' in i:
        jeans.append((df1[df1.name==i].index)[0])
    elif 'Trouser' in i or 'trouser' in i :
        trouser.append((df1[df1.name==i].index)[0])
    elif 'shirt' in i or 'Shirt' in i :
        shirt.append((df1[df1.name==i].index)[0])
    elif  'glasses' in i:
        glasses.append((df1[df1.name==i].index)[0])
    elif 'bra' in i or 'Bra' in i:
        bra.append((df1[df1.name==i].index)[0])
    elif 'jumper' in i or 'Jumper' in i:
        jumper.append((df1[df1.name==i].index)[0])
    elif 'hoodie' in i or 'Hoodie' in i:
        hoodie.append((df1[df1.name==i].index)[0])
    elif 'skirt' in i or 'Skirt' in i:
        skirt.append((df1[df1.name==i].index)[0])
    elif 'sneaker' in i or 'Sneaker' in i:
        sneaker.append((df1[df1.name==i].index)[0])
    elif 'shoe' in i or 'Shoe' in i:
        shoe.append((df1[df1.name==i].index)[0])

# %%
df1.loc[jeans]['name'].str.replace('-',' ').value_counts().head(20).plot(kind='bar')

# %%
df1.loc[trouser]['name'].str.replace('-',' ').value_counts().head(20).plot(kind='bar')

# %%
df1.loc[glasses]['name'].str.replace('-',' ').value_counts().head(20).plot(kind='bar')

# %%
df1.loc[jumper]['name'].str.replace('-',' ').value_counts().head(20).plot(kind='bar')

# %%
df1.loc[hoodie]['name'].str.replace('-',' ').value_counts().head(20).plot(kind='bar')

# %%
df1.loc[skirt]['name'].str.replace('-',' ').value_counts().head(20).plot(kind='bar')

# %%
df1.loc[sneaker]['name'].str.replace('-',' ').value_counts().head(20).plot(kind='bar')

# %%
df1.loc[shoe]['name'].str.replace('-',' ').value_counts().head(20).plot(kind='bar')

# %%
df1.loc[bra]['name'].str.replace('-',' ').value_counts().head(20).plot(kind='bar')

# %%
df1.num_of_orders.groupby(df1.brand_name).sum().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
df1.num_of_orders.groupby(df1.name).sum().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
df1.brand_name.value_counts().head(30)
# Out:
# next                 23208
# asos design          22857
# NA                    8427
# 4FASHION              5241
# nike                  3811
# river island          2865
# adidas                2393
# new look              2019
# lipsy                 1963
# prada                 1946
# gucci                 1887
# superdry              1685
# adidas originals      1625
# asos curve            1587
# 4fashion              1548
# dolce & gabbana       1538
# saint laurent         1462
# asos petite           1375
# dsquared2             1353
# diesel                1286
# boohoo                1257
# FASH                  1237
# asos tall             1223
# fat face              1184
# polo ralph lauren     1123
# burberry              1115
# GLOBALLE              1112
# tommy hilfiger        1093
# prettylittlething     1027
# calvin klein          1007
# Name: brand_name, dtype: int64

# %%
df1[df1.brand_name=='next']['name'].value_counts().head(20).plot(kind='bar')

# %%
df1[df1.brand_name=='asos design']['name'].value_counts().head(20).plot(kind='bar')

# %%
df1[df1.brand_name=='4FASHION']['name'].value_counts().head(20).plot(kind='bar')

# %%
df1[df1.brand_name=='nike']['name'].value_counts().head(20).plot(kind='bar')

# %%
df1[df1.brand_name=='adidas']['name'].value_counts().head(20).plot(kind='bar')

# %%
df1[df1.brand_name=='gucci']['name'].value_counts().head(20).plot(kind='bar')

# %%
sns.pairplot(df1)

# %%
import datetime

# %%
help(datetime.time)
# Out:
# Help on class time in module datetime:
#
# class time(builtins.object)
#  |  time([hour[, minute[, second[, microsecond[, tzinfo]]]]]) --> a time object
#  |
#  |  All arguments are optional. tzinfo may be None, or an instance of
#  |  a tzinfo subclass. The remaining arguments may be ints.
#  |
#  |  Methods defined here:
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(...)
#  |      Formats self with strftime.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __reduce__(...)
#  |      __reduce__() -> (cls, state)
#  |
# ...
